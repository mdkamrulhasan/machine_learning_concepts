# %% [markdown]
# <a href="https://colab.research.google.com/github/mdkamrulhasan/machine_learning_concepts/blob/master/notebooks/supervised/puzzle_Regression_insurance_cost_kNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solve the Puzzle (building a Regression pipline).
#
# ## **Insructions:**
#
# *   The code below woudn't run as the code is not ordered properly.
# *   You have to order the cells so we have a end-to-end classification model pipeline.
# *   Put descriptive comment a the first line of each cell.
# *   For example, the fourth cell should come at the beginning of your notebook, therefore we ranked it as (1.) and we added "loading packages" as it's corresponding comment.

# %%
##?? (Add a comment explaining the functionality of the code in this cell.)
TEST_PROP, RANDOM_SEED = 0.5, 0
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=TEST_PROP, random_state=RANDOM_SEED)

# %%
#
## ?? (Add a comment explaining the functionality of the code in this cell.)
feature_scaler = MinMaxScaler()
X = feature_scaler.fit_transform(df_all_numeric)

# %%
#?? (Add a comment explaining the functionality of the code in this cell.)
data_url = 'https://raw.githubusercontent.com/mdkamrulhasan/data_mining_kdd/main/data/medical-cost/insurance.csv'
df = pd.read_csv(data_url)
features_df, labels_df = df[df.columns[:-1]], df[df.columns[-1]]
y = labels_df.values

# %%
#?? (Add a comment explaining the functionality of the code in this cell.)
features_numeric = []
features_categorical = []
for colx in features_df.columns:
  if features_df[colx].dtype == 'object':
    #print(colx, df[colx].nunique())
    features_categorical.append(colx)
  else:
    features_numeric.append(colx)
print('numeric features:', features_numeric)
print('categorical features:', features_categorical)
# Out:
# numeric features: ['age', 'bmi', 'children']
# categorical features: ['sex', 'smoker', 'region']

# %%
#?? (Add a comment explaining the functionality of the code in this cell.)
one_hot_dataframes = []
for featx in features_categorical:
  one_hot_dataframes.append(
      pd.get_dummies(features_df[featx], prefix=featx+'_')
  )

df_all_numeric = pd.concat([features_df[features_numeric]]
                           + one_hot_dataframes, axis=1)

# %%
# 1. loading packages
from sklearn import datasets
from sklearn.datasets import load_breast_cancer
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import plotly.express as px
import plotly.graph_objects as go

# %%
#?? (Add a comment explaining the functionality of the code in this cell.)
y_pred = reg.predict(X_train)
acc_train = mean_squared_error(y_train, y_pred)
print("MSE (training data): %.2f" % acc_train)
y_pred = reg.predict(X_test)
acc_test = mean_squared_error(y_test, y_pred)
print("MSE (test data): %.2f" % acc_test)
# Out:
# MSE (training data): 29894571.83
# MSE (test data): 35777902.52

# %%
# ?? (Add a comment explaining the functionality of the code in this cell.)
reg = KNeighborsRegressor()
reg.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()
